# %% [markdown]
# <a href="https://colab.research.google.com/github/Davidchuramayta/trabajos/blob/main/SEN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# AQUI VA LA FUNCION DEL SENO

# %%
import math
import numpy as np
from matplotlib import pyplot as plt
#generamos los datos para el gráfico
x=np.arange(0,2.5+0.1,0.1)
y=np.zeros(len(x))
for i in range(len(x)):
  y[i]=math.sin(2*x[i])
#creamos el gráfico
plt.plot(x,y)
